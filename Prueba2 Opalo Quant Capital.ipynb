# %% [markdown]
# # Prueba: Ópalo Quant Capital

# %%
import pandas as pd
import numpy as np

from datetime import date, datetime, timedelta , time
from dateutil.relativedelta import relativedelta 


from sqlalchemy.sql import text

from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# #  Hola
#
#
# ######   Te agradecemos por participar en la prueba de Opalo Quant Cap, esperamos que hagas parte de nuestro equipo.
#
# #####  la prueba tiene 2 puntos:
# #####  el 1 primero relacionado con despliegue en la nube, micro servicios, decker,  y bd relacionales
# #####  el 2 segundo de programacion

# %% [markdown]
# # Primer punto

# %%
# Crear una  bd en postgres con la dos tablas que se  relacion abajo


historico_tasas_gen = pd.read_excel("01Tablas SQL.xlsx", sheet_name=  "historico_tasas_gen")
historico_tasas_gen.set_index("id_historico_tasas_gen", inplace = True)

historico_mercados = pd.read_excel("01Tablas SQL.xlsx", sheet_name=  "historico_mercados")
historico_mercados.set_index("fecha", inplace = True)


####################################### AWS  ##################################################################

# El objetivo es crear un micro servicion en "flask", o en "Fast api" o "django",
# contenerizadO en docker para exponer los endpoint, Entonces:

# despliegue la bd en AWS  y asi haga y  despligue en aws  una api rest  que  exponga la información de la bd
# cree los endpoint correspondientes al crud
# el codigo se debe poner en repositorio publico  junto con la coleccion de postman

####################################### ACTUALIZAR  #######################################
####################################### ACTUALIZAR  #######################################
####################################### ACTUALIZAR  #######################################
####################################### ACTUALIZAR  #######################################

#  escribir en este script el query que ejecute  la api  para actualiazar  en la bd

#    para la fecha "2021-04-11"
#    la tabla "historico_tasas_gen" 
#    de la columnas tasa, expectativa  y precio 
#    con  los datos  que se encuentran a continuacion

 
actualizar_tasas_gen = pd.read_excel("02datos actualizar.xlsx", sheet_name=  "historico_tasas_gen")
actualizar_tasas_gen.set_index("id_historico_tasas_gen", inplace = True)



#  escribir en este script el query que ejecute  la api  para actualiazar en la bd

#    para la fecha "2021-04-11"
#    de la tabla "historico_mercados" 
#    con  todas las  columnas con los datos  que se encuentran a continuacion



actualizar_mercados = pd.read_excel("02datos actualizar.xlsx", sheet_name=  "historico_mercados")
actualizar_mercados.set_index("fecha", inplace = True)


####################################### INSERTAR ####################################### 
####################################### INSERTAR ####################################### 
####################################### INSERTAR ####################################### 

#  escribir en este script el query que ejecute  la api  para insertar en la en bd

#    para la fecha "2021-04-12"
#    de la tabla "historico_tasas_gen" 
#    de todas las columnas   que se encuentran a continuacion


insertar_tasas_gen = pd.read_excel("03 datos insertar.xlsx", sheet_name=  "historico_tasas_gen")
insertar_tasas_gen.set_index("id_historico_tasas_gen", inplace = True)
insertar_tasas_gen


#  escribir en este script el query que ejecute  la api  para insertar en la bd

#    para la fecha "2021-04-12"
#    de la tabla "historico_mercados" 
#    de todas las columnas   que se encuentran a continuacion


insertar_mercados = pd.read_excel("03 datos insertar.xlsx", sheet_name=  "historico_mercados")
insertar_mercados.set_index("fecha", inplace = True)

# %% [markdown]
# # 2 Programacion

# %%
nombres =  [ "nicolas","samuel","mario","andrres","camilo"]

estatura = [ 1.70, 1.72,  1.75,  1.90,  1.68 ]
peso     = [ 67, 69,  72,  87,  65 ]

señal_1 = [ False,True,True,True,False]
señal_2 = [ True,True,False,True,True]



##  1) con los datos anteriorres
##     construya  dicicionarios con la estructura:
##     {nombre: estatrura}
##     {nombre: peso}
##     {nombre: señal_1}
##     {nombre: señal_2}

## 2) construya una funcion en la que se retorne un dicionario con {nombre: IMC} donde:
#      (IMC) indice de masa corporal = peso dividido la estatura al cuadrado
#
## 3) con los resultados construlla un df con las columnas "nombre"	"estatura"	"peso"	"imc"	señal_1	señal_2 
#
#
#
## 4) construya una funcion que recorra el dataframe 
#     y retorne el resultado de  multiplicar  el "imd" por raiz cuadrada de la "estatura",
#     donde para la la señal_1 ==  True y para  la señal_2 sea == False
#    para lo de mas retorne 0
#
#

#  5) inserte los resultado del recorridode la  funcion en una columna nueva del dataframe con el nombre de "resultado"
#
#
#
## 6) separe en un nuevo dataframe los datos de "camilo y de nicolas"
#
#
